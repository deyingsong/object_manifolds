# %% [markdown]
# # Mixed Integer Linear Programming (MILP)

# %% [markdown]
# ## Introduction
#
#
# - Some variables are restricted to be integers
# - NP-complete
# - Applications
#   - Production planning
#   - Scheduling
#   - Many more...
#
# ### The Standard Form
#
# Maximize
#
# $$
# c^T x + k^T y
# $$
#
# subject to
#
# $$
# Ax \le b
# $$
#
# $$
# Dy \le e
# $$
#
# $$
# x, y \ge 0
# $$
#
# $$
# x \in \mathbb{Z}^n
# $$
#
# where $A, D \in \mathbb{R}^{m \times n}$ are matrices, $b, e \in \mathbb{R}^m$ are constants, $c, k \in \mathbb{R}^n$ are objective function coefficients, and $x, y \in \mathbb{R}^n$ are the decision variables.

# %% [markdown]
# ## CPLEX basics: Mixed Integer Progamming Model
#
# ## Mathematical Model
#
# Maximize
#
# $$
# 2x + y + 3z
# $$
#
# subject to
#
# $$
# x + 2y + z \le 4
# $$
#
# $$
# 2z + y \le 5
# $$
#
# $$
# x + y \ge 1
# $$
#
# $$
# x \in \{0, 1\}
# $$
#
# $$
# y, z \ge 0
# $$
#
# $$
# z \in \mathbb{Z}
# $$

# %% [markdown]
# ## Code in Python using docplex

# %% [markdown]
# ### Step 1: importing model from docplex package

# %%
from docplex.mp.model import Model

# %% [markdown]
# ### Step 2: Create an optimization model

# %%
milp_model = Model(name='MILP')

# %% [markdown]
# ### Step 3: Add decision varialbes

# %%
x = milp_model.binary_var(name='x')
y = milp_model.continuous_var(name='y', lb=0)
z = milp_model.integer_var(name='z', lb=0)

# %% [markdown]
# ### Step 4: Add the constraints

# %%
c1 = milp_model.add_constraint(x + 2*y + z <= 4, ctname='c1')
c2 = milp_model.add_constraint(2*z + y <=5, ctname='c2')
c3 = milp_model.add_constraint(x + z >= 1, ctname='c3')

# %% [markdown]
# ### Step 5: Define the objective function

# %%
obj_fn = 2*x + y + 3*z
milp_model.set_objective('max', obj_fn)

milp_model.print_information()
# Out:
# Model: MILP
#  - number of variables: 3
#    - binary=1, integer=1, continuous=1
#  - number of constraints: 3
#    - linear=3
#  - parameters: defaults
#  - objective: maximize
#  - problem type is: MILP

# %% [markdown]
# ### Step 6: Solve the model

# %%
milp_model.solve()
# Out:
# docplex.mp.solution.SolveSolution(obj=8.5,values={x:1,y:0.5,z:2})

# %% [markdown]
# ### Step 7: Output the result

# %%
milp_model.print_solution()
# Out:
# objective: 8.500
# status: OPTIMAL_SOLUTION(2)
#   x=1
#   y=0.500
#   z=2
